# %%
#imports
import pandas as pd
import warnings
from datetime import time

# %%
warnings.filterwarnings('ignore')

# %%
employeeDF = pd.read_csv('employees_info.csv')
employeeDF
# Out:
#     EmployeeID firstName         lastName  Age                       Position  \
# 0            1    Brandy          Abshire   24             Marketing Director
# 1            2     Bryan          Lafitte   45                        Manager
# 2            3    Pierre             Ponz   25                    Pastry Chef
# 3            4     Ebony         Lafyette   19                Sales Associate
# 4            5     Emory         Williams   39                    Pastry Chef
# 5            6      Ella             Alef   47                        Manager
# 6            7      Leah            Chase   60                    Pastry Chef
# 7            8      Adam          Lagasse   35                Sales Associate
# 8            9   DeWhite          Pemonte   30                Sales Associate
# 9           10      Anne            Rause   51                Sales Associate
# 10          11   Micheal             Hugh   35  Director of Online Operations
# ...

# %%
#replace NaN with another value
employeeDF.fillna('online', inplace=True)
employeeDF
# Out:
#     EmployeeID firstName         lastName  Age                       Position  \
# 0            1    Brandy          Abshire   24             Marketing Director
# 1            2     Bryan          Lafitte   45                        Manager
# 2            3    Pierre             Ponz   25                    Pastry Chef
# 3            4     Ebony         Lafyette   19                Sales Associate
# 4            5     Emory         Williams   39                    Pastry Chef
# 5            6      Ella             Alef   47                        Manager
# 6            7      Leah            Chase   60                    Pastry Chef
# 7            8      Adam          Lagasse   35                Sales Associate
# 8            9   DeWhite          Pemonte   30                Sales Associate
# 9           10      Anne            Rause   51                Sales Associate
# 10          11   Micheal             Hugh   35  Director of Online Operations
# ...

# %%
employeeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  19 non-null     int64
#  1   firstName   19 non-null     object
#  2   lastName    19 non-null     object
#  3   Age         19 non-null     int64
#  4   Position    19 non-null     object
#  5   HireDate    19 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.0+ KB

# %%
#convert HireDate column to date data type
employeeDF['HireDate'] = pd.to_datetime(employeeDF['HireDate'], errors='coerce')

# %%
employeeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  19 non-null     int64
#  1   firstName   19 non-null     object
#  2   lastName    19 non-null     object
#  3   Age         19 non-null     int64
#  4   Position    19 non-null     object
#  5   HireDate    19 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 1.0+ KB

# %%
#export as csv file
employeeDF.to_csv('clean_employee_2022.csv', index=False)
